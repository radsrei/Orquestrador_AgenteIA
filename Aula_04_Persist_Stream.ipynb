# %%
# %pip install python-dotenv
# %pip install -U langgraph langchain langchain-google-genai langchain-tavily python-dotenv aiosqlite
# Out:
# Requirement already satisfied: python-dotenv in c:\users\cadup\anaconda3\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: langgraph in c:\users\cadup\anaconda3\lib\site-packages (0.6.5)
# Collecting langgraph
#   Downloading langgraph-0.6.6-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: langchain in c:\users\cadup\anaconda3\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-google-genai in c:\users\cadup\anaconda3\lib\site-packages (2.1.9)
# Requirement already satisfied: langchain-tavily in c:\users\cadup\anaconda3\lib\site-packages (0.2.11)
# Requirement already satisfied: python-dotenv in c:\users\cadup\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: aiosqlite in c:\users\cadup\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\cadup\anaconda3\lib\site-packages (from langgraph) (0.3.74)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in c:\users\cadup\anaconda3\lib\site-packages (from langgraph) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in c:\users\cadup\anaconda3\lib\site-packages (from langgraph) (0.6.3)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph)
#   Downloading langgraph_sdk-0.2.2-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\cadup\anaconda3\lib\site-packages (from langgraph) (2.11.7)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\cadup\anaconda3\lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\cadup\anaconda3\lib\site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\cadup\anaconda3\lib\site-packages (from langchain) (0.4.13)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\cadup\anaconda3\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\cadup\anaconda3\lib\site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\cadup\anaconda3\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\cadup\anaconda3\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in c:\users\cadup\anaconda3\lib\site-packages (from langchain-google-genai) (0.6.18)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in c:\users\cadup\anaconda3\lib\site-packages (from langchain-tavily) (3.12.14)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\cadup\anaconda3\lib\site-packages (from aiosqlite) (4.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\cadup\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\cadup\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\cadup\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\cadup\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\cadup\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\cadup\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\cadup\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.20.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\cadup\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.25.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\cadup\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.40.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\cadup\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\cadup\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.29.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\cadup\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\cadup\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: packaging>=23.2 in c:\users\cadup\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (24.2)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\cadup\anaconda3\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\cadup\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\cadup\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\cadup\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\cadup\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\cadup\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\cadup\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\cadup\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cadup\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cadup\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cadup\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cadup\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in c:\users\cadup\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\cadup\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\cadup\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\cadup\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\cadup\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cadup\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\cadup\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (4.9.1)
# Requirement already satisfied: anyio in c:\users\cadup\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\cadup\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\cadup\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\cadup\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\cadup\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\cadup\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.3.1)
# Downloading langgraph-0.6.6-py3-none-any.whl (153 kB)
#    ---------------------------------------- 0.0/153.3 kB ? eta -:--:--
#    ----- --------------------------------- 20.5/153.3 kB 640.0 kB/s eta 0:00:01
#    ------------------ -------------------- 71.7/153.3 kB 975.2 kB/s eta 0:00:01
#    ------------------------------------- -- 143.4/153.3 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 153.3/153.3 kB 1.3 MB/s eta 0:00:00
# Downloading langgraph_sdk-0.2.2-py3-none-any.whl (52 kB)
#    ---------------------------------------- 0.0/52.0 kB ? eta -:--:--
#    ---------------------------------------- 52.0/52.0 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: langgraph-sdk, langgraph
#   Attempting uninstall: langgraph-sdk
#     Found existing installation: langgraph-sdk 0.2.0
#     Uninstalling langgraph-sdk-0.2.0:
#       Successfully uninstalled langgraph-sdk-0.2.0
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 0.6.5
#     Uninstalling langgraph-0.6.5:
#       Successfully uninstalled langgraph-0.6.5
# Successfully installed langgraph-0.6.6 langgraph-sdk-0.2.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
#     WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
#     WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\cadup\anaconda3\Lib\site-packages\httpx-0.27.2.dist-info due to invalid metadata entry 'name'

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ['GOOGLE_API_KEY'] = os.getenv('GEMINI_API_KEY') 
os.environ['TAVILY_API_KEY'] = os.getenv('TAVILY_API_KEY')

# %%
import operator
from typing import Annotated, List, Any, Dict
from dataclasses import dataclass, field
from langgraph.graph import StateGraph, END
from langchain_core.messages import HumanMessage, SystemMessage, ToolMessage, BaseMessage, AnyMessage

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_tavily import TavilySearch

from langgraph.checkpoint.sqlite import SqliteSaver

from typing_extensions import TypedDict

import sqlite3

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

conn = sqlite3.connect("checkpoints.db", check_same_thread=False)
memory = SqliteSaver(conn)

# %%
class Agent:
    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        
        graph = StateGraph(AgentState)

        graph.add_node("llm", self.call_gemini)

        graph.add_node("action", self.take_action)

        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})

        graph.add_edge("action", "llm")

        graph.set_entry_point("llm")

        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_gemini(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages

        print("Mensagens enviadas ao modelo:", messages)
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling Tool: {t['name']} with args: {t['args']}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Returning to LLM after action!")
        return {'messages': results}

# %%
current_tavily_api_key = os.getenv('TAVILY_API_KEY')
if not current_tavily_api_key:
    raise ValueError("TAVILY_API_KEY não encontrada. Certifique-se de que está no seu .env e python-dotenv está instalado.")

tool = TavilySearch(max_results=3, tavily_api_key=current_tavily_api_key)


prompt_system = """Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.
Você tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).
Busque informações apenas quando tiver certeza do que procurar.
Se precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.
Quando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas."""

model = ChatGoogleGenerativeAI(model="gemini-1.5-pro") 

abot = Agent(model, [tool], system=prompt_system, checkpointer=memory)

# %%
messages = [HumanMessage(content="Como está o tempo em São Paulo hoje (21/08/2025)?")]
thread = {"configurable": {"thread_id": "1"}} 


print("\n--- Pergunta 1: Tempo em São Paulo ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"): 
             print(f"{k}: {v['messages']}")
# Out:
# --- Pergunta 1: Tempo em São Paulo ---
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje?', additional_kwargs={}, response_metadata={}), AIMessage(content='Preciso de mais informações para responder à sua pergunta. Você poderia me dizer a data de hoje?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--e1b14eca-b272-467e-b68a-b286be59f401-0', usage_metadata={'input_tokens': 1212, 'output_tokens': 21, 'total_tokens': 1233, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Como está o tempo em São Paulo hoje (21/08/2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"time_range": "day", "query": "Weather in S\\u00e3o Paulo on 2025-08-21"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--7434c81a-95eb-4be0-85b7-d74d56a756cb-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'Weather in São Paulo on 2025-08-21'}, 'id': 'f88914a8-6257-4716-89c2-a461387af71b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1252, 'output_tokens': 25, 'total_tokens': 1277, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{\'query\': \'Weather in São Paulo on 2025-08-21\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in São Paulo\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'error\': {\'code\': 1006, \'message\': \'No matching location found.\'}}", \'score\': 0.7878437, \'raw_content\': None}, {\'url\': \'https://www.flightaware.com/live/flight/GLO1241/history/20250821/0945Z/SBMG/SBGR\', \'title\': \'G31241 (GLO1241) GOL Linhas Aéreas Inteligentes Flight Tracking ...\', \'content\': "Weather Radar. Worldwide Weather. Weather Radar (Premium). Satellite IR ... 08:00AM -03 São Paulo-Guarulhos Int\'l - GRU. B738. 1h 25m. Thursday 21-Aug-2025.", \'score\': 0.63098115, \'raw_content\': None}, {\'url\': \'https://www.klm.co.uk/en-gb/flights-from-teesside-to-sao-paulo\', \'title\': \'Flight deals from Teesside to Sao Paulo | KLM\', \'content\': \'Weather in Sao Paulo ; Tuesday. few clouds. 22°C · 19/08/2025 ; Wednesday. sky is clear. 30°C · 20/08/2025 ; Thursday. sky is clear. 31°C · 21/08/2025 ; Friday.\', \'score\': 0.5752307, \'raw_content\': None}], \'response_time\': 2.01, \'request_id\': \'588b21c2-e4a3-4449-8ff2-1d9afb4ba755\'}', name='tavily_search', tool_call_id='f88914a8-6257-4716-89c2-a461387af71b'), AIMessage(content='A previsão do tempo para São Paulo em 21 de agosto de 2025 é de céu limpo com 31°C.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--49bbcda5-7bb6-49f3-8dad-4def1cde0f7d-0', usage_metadata={'input_tokens': 1763, 'output_tokens': 31, 'total_tokens': 1794, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='E no Rio de Janeiro?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_searc ...
# llm: [AIMessage(content='A previsão do tempo para São Paulo em 21 de agosto de 2025 é de céu limpo com 31°C.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--40f5fba6-ebbe-4d68-a5c1-c190bd4e605c-0', usage_metadata={'input_tokens': 3316, 'output_tokens': 31, 'total_tokens': 3347, 'input_token_details': {'cache_read': 0}})]

# %%
messages = [HumanMessage(content="E no Rio de Janeiro?")]
thread = {"configurable": {"thread_id": "1"}} 

print("\n--- Pergunta 2: Tempo no Rio de Janeiro ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pergunta 2: Tempo no Rio de Janeiro ---
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje?', additional_kwargs={}, response_metadata={}), AIMessage(content='Preciso de mais informações para responder à sua pergunta. Você poderia me dizer a data de hoje?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--e1b14eca-b272-467e-b68a-b286be59f401-0', usage_metadata={'input_tokens': 1212, 'output_tokens': 21, 'total_tokens': 1233, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Como está o tempo em São Paulo hoje (21/08/2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"time_range": "day", "query": "Weather in S\\u00e3o Paulo on 2025-08-21"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--7434c81a-95eb-4be0-85b7-d74d56a756cb-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'Weather in São Paulo on 2025-08-21'}, 'id': 'f88914a8-6257-4716-89c2-a461387af71b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1252, 'output_tokens': 25, 'total_tokens': 1277, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{\'query\': \'Weather in São Paulo on 2025-08-21\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in São Paulo\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'error\': {\'code\': 1006, \'message\': \'No matching location found.\'}}", \'score\': 0.7878437, \'raw_content\': None}, {\'url\': \'https://www.flightaware.com/live/flight/GLO1241/history/20250821/0945Z/SBMG/SBGR\', \'title\': \'G31241 (GLO1241) GOL Linhas Aéreas Inteligentes Flight Tracking ...\', \'content\': "Weather Radar. Worldwide Weather. Weather Radar (Premium). Satellite IR ... 08:00AM -03 São Paulo-Guarulhos Int\'l - GRU. B738. 1h 25m. Thursday 21-Aug-2025.", \'score\': 0.63098115, \'raw_content\': None}, {\'url\': \'https://www.klm.co.uk/en-gb/flights-from-teesside-to-sao-paulo\', \'title\': \'Flight deals from Teesside to Sao Paulo | KLM\', \'content\': \'Weather in Sao Paulo ; Tuesday. few clouds. 22°C · 19/08/2025 ; Wednesday. sky is clear. 30°C · 20/08/2025 ; Thursday. sky is clear. 31°C · 21/08/2025 ; Friday.\', \'score\': 0.5752307, \'raw_content\': None}], \'response_time\': 2.01, \'request_id\': \'588b21c2-e4a3-4449-8ff2-1d9afb4ba755\'}', name='tavily_search', tool_call_id='f88914a8-6257-4716-89c2-a461387af71b'), AIMessage(content='A previsão do tempo para São Paulo em 21 de agosto de 2025 é de céu limpo com 31°C.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--49bbcda5-7bb6-49f3-8dad-4def1cde0f7d-0', usage_metadata={'input_tokens': 1763, 'output_tokens': 31, 'total_tokens': 1794, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='E no Rio de Janeiro?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_searc ...
# llm: [AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"time_range": "day", "query": "Weather in Rio de Janeiro on 2025-08-21"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--76c37891-1689-416d-a7ce-08b84494e0d7-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'Weather in Rio de Janeiro on 2025-08-21'}, 'id': 'c1f27151-5a49-4330-8b64-79be4a3c814f', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3352, 'output_tokens': 26, 'total_tokens': 3378, 'input_token_details': {'cache_read': 0}})]
# Calling Tool: tavily_search with args: {'time_range': 'day', 'query': 'Weather in Rio de Janeiro on 2025-08-21'}
# Returning to LLM after action!
# action: [ToolMessage(content='{\'query\': \'Weather in Rio de Janeiro on 2025-08-21\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Rio de Janeiro\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'error\': {\'code\': 1006, \'message\': \'No matching location found.\'}}", \'score\': 0.9068441, \'raw_content\': None}, {\'url\': \'https://www.timeanddate.com/weather/brazil/rio-de-janeiro/hourly\', \'title\': \'Hour-by-hour Forecast in Rio de Janeiro - Brazil - Time and Date\', \'content\': \'*   Time Zone News *   Calendar & Holiday News *   Time Zones *   Time Zones Home *   Time Changes Worldwide *   Time Zone News *   Calendar & Holiday News *   Weather *   Moon Calculator *   Calculators *   Calculators Home *   My Privacy *   Weather *   Time Zone Image 3: Sunny.Currently: 81°F. See Extended Forecast for more weather Show weather on:   | 7:00 am | Image 20: Sunny. | 8:00 am | Image 21: Sunny. | 9:00 am | Image 22: Sunny. | 10:00 am | Image 23: Sunny. | 11:00 am | Image 24: Sunny. | * Updated Wednesday, August 20, 2025 10:42:30 am Rio de Janeiro time - Weather by CustomWeather, © 2025 | *   Time Zones *   Weather *   Calculators\', \'score\': 0.6202772, \'raw_content\': None}, {\'url\': \'https://www.ventusky.com/rio-de-janeiro\', \'title\': \'Rio de Janeiro - Weather Forecast Maps - Ventusky\', \'content\': \'Rio de Janeiro ☀ ✓ Weather forecast for 10 days, information from meteorological stations, webcams, sunrise and sunset, wind and precipitation maps for this\', \'score\': 0.3093475, \'raw_content\': None}], \'response_time\': 1.11, \'request_id\': \'b17a48c5-f99b-421e-bedf-09f02e07f00a\'}', name='tavily_search', tool_call_id='c1f27151-5a49-4330-8b64-79be4a3c814f')]
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje?', additional_kwargs={}, response_metadata={}), AIMessage(content='Preciso de mais informações para responder à sua pergunta. Você poderia me dizer a data de hoje?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--e1b14eca-b272-467e-b68a-b286be59f401-0', usage_metadata={'input_tokens': 1212, 'output_tokens': 21, 'total_tokens': 1233, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Como está o tempo em São Paulo hoje (21/08/2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"time_range": "day", "query": "Weather in S\\u00e3o Paulo on 2025-08-21"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--7434c81a-95eb-4be0-85b7-d74d56a756cb-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'Weather in São Paulo on 2025-08-21'}, 'id': 'f88914a8-6257-4716-89c2-a461387af71b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1252, 'output_tokens': 25, 'total_tokens': 1277, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{\'query\': \'Weather in São Paulo on 2025-08-21\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in São Paulo\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'error\': {\'code\': 1006, \'message\': \'No matching location found.\'}}", \'score\': 0.7878437, \'raw_content\': None}, {\'url\': \'https://www.flightaware.com/live/flight/GLO1241/history/20250821/0945Z/SBMG/SBGR\', \'title\': \'G31241 (GLO1241) GOL Linhas Aéreas Inteligentes Flight Tracking ...\', \'content\': "Weather Radar. Worldwide Weather. Weather Radar (Premium). Satellite IR ... 08:00AM -03 São Paulo-Guarulhos Int\'l - GRU. B738. 1h 25m. Thursday 21-Aug-2025.", \'score\': 0.63098115, \'raw_content\': None}, {\'url\': \'https://www.klm.co.uk/en-gb/flights-from-teesside-to-sao-paulo\', \'title\': \'Flight deals from Teesside to Sao Paulo | KLM\', \'content\': \'Weather in Sao Paulo ; Tuesday. few clouds. 22°C · 19/08/2025 ; Wednesday. sky is clear. 30°C · 20/08/2025 ; Thursday. sky is clear. 31°C · 21/08/2025 ; Friday.\', \'score\': 0.5752307, \'raw_content\': None}], \'response_time\': 2.01, \'request_id\': \'588b21c2-e4a3-4449-8ff2-1d9afb4ba755\'}', name='tavily_search', tool_call_id='f88914a8-6257-4716-89c2-a461387af71b'), AIMessage(content='A previsão do tempo para São Paulo em 21 de agosto de 2025 é de céu limpo com 31°C.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--49bbcda5-7bb6-49f3-8dad-4def1cde0f7d-0', usage_metadata={'input_tokens': 1763, 'output_tokens': 31, 'total_tokens': 1794, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='E no Rio de Janeiro?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_searc ...
# llm: [AIMessage(content='Eu não consegui encontrar a previsão do tempo para o Rio de Janeiro especificamente no dia 21 de agosto de 2025. As informações que encontrei indicam que em 20 de agosto de 2025 o tempo estaria ensolarado com 27°C (81°F).', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--16baed5b-a97e-4ac0-9d16-f4cf75b47cc7-0', usage_metadata={'input_tokens': 3935, 'output_tokens': 69, 'total_tokens': 4004, 'input_token_details': {'cache_read': 0}})]

# %%
messages = [HumanMessage(content="Qual está mais quente?")]
thread = {"configurable": {"thread_id": "1"}} 

print("\n--- Pergunta 3: Comparação ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pergunta 3: Comparação ---
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje?', additional_kwargs={}, response_metadata={}), AIMessage(content='Preciso de mais informações para responder à sua pergunta. Você poderia me dizer a data de hoje?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--e1b14eca-b272-467e-b68a-b286be59f401-0', usage_metadata={'input_tokens': 1212, 'output_tokens': 21, 'total_tokens': 1233, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Como está o tempo em São Paulo hoje (21/08/2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"time_range": "day", "query": "Weather in S\\u00e3o Paulo on 2025-08-21"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--7434c81a-95eb-4be0-85b7-d74d56a756cb-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'Weather in São Paulo on 2025-08-21'}, 'id': 'f88914a8-6257-4716-89c2-a461387af71b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1252, 'output_tokens': 25, 'total_tokens': 1277, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{\'query\': \'Weather in São Paulo on 2025-08-21\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in São Paulo\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'error\': {\'code\': 1006, \'message\': \'No matching location found.\'}}", \'score\': 0.7878437, \'raw_content\': None}, {\'url\': \'https://www.flightaware.com/live/flight/GLO1241/history/20250821/0945Z/SBMG/SBGR\', \'title\': \'G31241 (GLO1241) GOL Linhas Aéreas Inteligentes Flight Tracking ...\', \'content\': "Weather Radar. Worldwide Weather. Weather Radar (Premium). Satellite IR ... 08:00AM -03 São Paulo-Guarulhos Int\'l - GRU. B738. 1h 25m. Thursday 21-Aug-2025.", \'score\': 0.63098115, \'raw_content\': None}, {\'url\': \'https://www.klm.co.uk/en-gb/flights-from-teesside-to-sao-paulo\', \'title\': \'Flight deals from Teesside to Sao Paulo | KLM\', \'content\': \'Weather in Sao Paulo ; Tuesday. few clouds. 22°C · 19/08/2025 ; Wednesday. sky is clear. 30°C · 20/08/2025 ; Thursday. sky is clear. 31°C · 21/08/2025 ; Friday.\', \'score\': 0.5752307, \'raw_content\': None}], \'response_time\': 2.01, \'request_id\': \'588b21c2-e4a3-4449-8ff2-1d9afb4ba755\'}', name='tavily_search', tool_call_id='f88914a8-6257-4716-89c2-a461387af71b'), AIMessage(content='A previsão do tempo para São Paulo em 21 de agosto de 2025 é de céu limpo com 31°C.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--49bbcda5-7bb6-49f3-8dad-4def1cde0f7d-0', usage_metadata={'input_tokens': 1763, 'output_tokens': 31, 'total_tokens': 1794, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='E no Rio de Janeiro?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_searc ...
# llm: [AIMessage(content='São Paulo está mais quente, com previsão de 31°C no dia 21 de agosto de 2025. A temperatura prevista para o Rio de Janeiro no dia *20* de agosto de 2025 é de 27°C. Não tenho a previsão para o Rio de Janeiro no dia 21.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--c9f557d8-a83a-4a71-aefc-b458f693ff6e-0', usage_metadata={'input_tokens': 4008, 'output_tokens': 74, 'total_tokens': 4082, 'input_token_details': {'cache_read': 0}})]

# %%
messages = [HumanMessage(content="Qual está mais quente?")]
thread = {"configurable": {"thread_id": "2"}} 

print("\n--- Pergunta 4: Comparação ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pergunta 4: Comparação ---
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--a8133944-57a7-4ad9-9fc0-cd36d1a61a45-0', usage_metadata={'input_tokens': 1208, 'output_tokens': 23, 'total_tokens': 1231, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--00d82cce-7911-4134-841a-b311997fe866-0', usage_metadata={'input_tokens': 1236, 'output_tokens': 24, 'total_tokens': 1260, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--4b0fd3d1-0a78-4646-95df-1cd94302ea17-0', usage_metadata={'input_tokens': 1264, 'output_tokens': 24, 'total_tokens': 1288, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--9b02ee4f-9ea4-4135-b4f0-ec9ad4fbf85c-0', usage_metadata={'input_tokens': 1292, 'output_tokens': 24, 'total_tokens': 1316, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--cbebb9e5-468b-4a3d-b93c-012e2cffccc9-0', usage_metadata={'input_tokens': 1320, 'output_tokens': 24, 'total_tokens': 1344, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--c1dda1f6-c290-4923-8192-766db87533c6-0', usage_metadata={' ...
# llm: [AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--09fe973d-0d81-4d11-a5ea-7ae528929c6d-0', usage_metadata={'input_tokens': 5752, 'output_tokens': 24, 'total_tokens': 5776, 'input_token_details': {'cache_read': 0}})]
